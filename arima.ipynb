# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("AAP_data.csv", index_col=['date'], parse_dates=['date'], dayfirst=True)
df.head()
# Out:
#              open   high      low  close   volume Name
# date
# 2013-02-08  78.34  79.72  78.0100  78.90  1298137  AAP
# 2013-02-11  78.65  78.91  77.2300  78.39   758016  AAP
# 2013-02-12  78.39  78.63  77.5132  78.60   876859  AAP
# 2013-02-13  78.90  79.13  77.8500  78.97  1038574  AAP
# 2013-02-14  78.66  79.72  78.5850  78.84  1005376  AAP

# %%
df['volume'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.plot(subplots=True, figsize=(10,12))
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>], dtype=object)

# %%
df_month = df.resample("M").mean()
# Out:
# <ipython-input-19-b61cfce1fd0a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_month = df.resample("M").mean()

# %%
from matplotlib import pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(
    df_month['2013':].index, 
    df_month.loc['2013':, 'volume'], 
    width=25, align='center')
# Out:
# <BarContainer object of 61 artists>

# %%
import statsmodels.api as sm
from statsmodels.iolib.table import SimpleTable

# %%
ig = plt.figure(figsize=(12,10))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['volume'].values.squeeze(), lags=25)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['volume'], lags=25)
